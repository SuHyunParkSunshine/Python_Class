# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'}

response = requests.get('https://www.genie.co.kr/search/searchSong?Coll=sAll&query=%25EC%2584%25B8%25EB%25B8%2590%25ED%258B%25B4&page=1&pagesize=20&of=POPULAR&fscount=&Genre=&Country=&reQuery=&researchyn=N', headers=headers)

soup = BeautifulSoup(response.text, 'html.parser')

trs = soup.select('#body-content > div.search_song > div.music-list-wrap > div.music-list-wrap > table > tbody > tr')
trs
# Out:
# [<tr class="list" songid="101479700">
#  <td class="check"><input class="select-check" title="손오공
#  " type="checkbox"/></td>
#  <td class="number">1</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83762577');return false;"><span class="mask"></span><img alt="손오공" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('101479700');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('101479700;','1');return false;" title="손오공
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															손오공
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('101479700'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_101479700"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83762577');return false;">
#
#
#
#  													SEVENTEEN 10th Mini Album 'FML'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('101479700;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('101479700;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_101479700" onclick="fnAddMyAlbumForm('#add_my_album_101479700' , '101479700' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('101479700');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_101479700">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('101479700','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('101479700');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('101479700');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="101479699">
#  <td class="check"><input class="select-check" title="f*ck my life
#  " type="checkbox"/></td>
#  <td class="number">2</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83762577');return false;"><span class="mask"></span><img alt="F*ck My Life" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('101479699');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('101479699;','1');return false;" title="f*ck my life
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															F*ck My Life
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('101479699'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_101479699"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83762577');return false;">
#
#
#
#  													SEVENTEEN 10th Mini Album 'FML'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('101479699;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('101479699;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_101479699" onclick="fnAddMyAlbumForm('#add_my_album_101479699' , '101479699' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('101479699');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_101479699">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('101479699','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('101479699');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('101479699');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="101479703">
#  <td class="check"><input class="select-check" title="먼지
#  " type="checkbox"/></td>
#  <td class="number">3</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83762577');return false;"><span class="mask"></span><img alt="먼지" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('101479703');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('101479703;','1');return false;" title="먼지
#  ">
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															먼지
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('101479703'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_101479703"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83762577');return false;">
#
#
#
#  													SEVENTEEN 10th Mini Album 'FML'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('101479703;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('101479703;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_101479703" onclick="fnAddMyAlbumForm('#add_my_album_101479703' , '101479703' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('101479703');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_101479703">
#  <a class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('101479703');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('101479703');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="101479704">
#  <td class="check"><input class="select-check" title="april shower
#  " type="checkbox"/></td>
#  <td class="number">4</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83762577');return false;"><span class="mask"></span><img alt="April shower" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('101479704');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('101479704;','1');return false;" title="april shower
#  ">
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															April shower
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('101479704'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_101479704"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83762577');return false;">
#
#
#
#  													SEVENTEEN 10th Mini Album 'FML'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('101479704;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('101479704;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_101479704" onclick="fnAddMyAlbumForm('#add_my_album_101479704' , '101479704' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('101479704');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_101479704">
#  <a class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('101479704');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('101479704');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="101479702">
#  <td class="check"><input class="select-check" title="i don't understand but i luv u
#  " type="checkbox"/></td>
#  <td class="number">5</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83762577');return false;"><span class="mask"></span><img alt="I Don't Understand But I Luv U" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('101479702');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('101479702;','1');return false;" title="i don't understand but i luv u
#  ">
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															I Don't Understand But I Luv U
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('101479702'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_101479702"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83762577');return false;">
#
#
#
#  													SEVENTEEN 10th Mini Album 'FML'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('101479702;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('101479702;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_101479702" onclick="fnAddMyAlbumForm('#add_my_album_101479702' , '101479702' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('101479702');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_101479702">
#  <a class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('101479702');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('101479702');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="101479701">
#  <td class="check"><input class="select-check" title="fire
#  " type="checkbox"/></td>
#  <td class="number">6</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83762577');return false;"><span class="mask"></span><img alt="Fire" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/083/762/577/83762577_1682297728199_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('101479701');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('101479701;','1');return false;" title="fire
#  ">
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															Fire
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('101479701'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_101479701"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83762577');return false;">
#
#
#
#  													SEVENTEEN 10th Mini Album 'FML'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('101479701;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('101479701;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_101479701" onclick="fnAddMyAlbumForm('#add_my_album_101479701' , '101479701' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('101479701');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_101479701">
#  <a class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('101479701');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('101479701');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="96899921">
#  <td class="check"><input class="select-check" title="hot
#  " type="checkbox"/></td>
#  <td class="number">7</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82639088');return false;"><span class="mask"></span><img alt="HOT" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/639/088/82639088_1653623843808_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/082/639/088/82639088_1653623843808_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96899921');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('96899921;','1');return false;" title="hot
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															HOT
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('96899921'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_96899921"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82639088');return false;">
#
#
#
#  													SEVENTEEN 4th Album 'Face the Sun'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96899921;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('96899921;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_96899921" onclick="fnAddMyAlbumForm('#add_my_album_96899921' , '96899921' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('96899921');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_96899921">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('96899921','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('96899921');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('96899921');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="86418700">
#  <td class="check"><input class="select-check" title="아주 nice
#  " type="checkbox"/></td>
#  <td class="number">8</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('80839512');return false;"><span class="mask"></span><img alt="아주 NICE" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/080/839/512/80839512_1467554077824_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/080/839/512/80839512_1467554077824_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('86418700');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('86418700;','1');return false;" title="아주 nice
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															아주 NICE
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('86418700'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_86418700"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('80839512');return false;">
#
#
#
#  													Love&amp;Letter (Repackage Album)
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('86418700;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('86418700;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_86418700" onclick="fnAddMyAlbumForm('#add_my_album_86418700' , '86418700' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('86418700');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_86418700">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('86418700','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('86418700');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('86418700');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="97390688">
#  <td class="check"><input class="select-check" title="_world
#  " type="checkbox"/></td>
#  <td class="number">9</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82812828');return false;"><span class="mask"></span><img alt="_WORLD" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/812/828/82812828_1658125476932_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/082/812/828/82812828_1658125476932_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('97390688');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('97390688;','1');return false;" title="_world
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															_WORLD
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('97390688'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_97390688"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82812828');return false;">
#
#
#
#  													SEVENTEEN 4th Album Repackage 'SECTOR 17'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('97390688;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('97390688;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_97390688" onclick="fnAddMyAlbumForm('#add_my_album_97390688' , '97390688' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('97390688');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_97390688">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('97390688','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('97390688');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('97390688');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="86180387">
#  <td class="check"><input class="select-check" title="예쁘다
#  " type="checkbox"/></td>
#  <td class="number">10</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('80812544');return false;"><span class="mask"></span><img alt="예쁘다" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/080/812/544/80812544_1461508310884_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/080/812/544/80812544_1461508310884_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('86180387');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('86180387;','1');return false;" title="예쁘다
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															예쁘다
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('86180387'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_86180387"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('80812544');return false;">
#
#
#
#  													SEVENTEEN 1ST ALBUM (FIRST 'LOVE&amp;LETTER')
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('86180387;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('86180387;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_86180387" onclick="fnAddMyAlbumForm('#add_my_album_86180387' , '86180387' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('86180387');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_86180387">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('86180387','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('86180387');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('86180387');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="96555053">
#  <td class="check"><input class="select-check" title="darl＋ing
#  " type="checkbox"/></td>
#  <td class="number">11</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82639088');return false;"><span class="mask"></span><img alt="Darl＋ing" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/639/088/82639088_1653623843808_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/082/639/088/82639088_1653623843808_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('96555053');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('96555053;','1');return false;" title="darl＋ing
#  ">
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															Darl＋ing
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('96555053'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_96555053"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82639088');return false;">
#
#
#
#  													SEVENTEEN 4th Album 'Face the Sun'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('96555053;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('96555053;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_96555053" onclick="fnAddMyAlbumForm('#add_my_album_96555053' , '96555053' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('96555053');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_96555053">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('96555053','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('96555053');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('96555053');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="94692075">
#  <td class="check"><input class="select-check" title="rock with you
#  " type="checkbox"/></td>
#  <td class="number">12</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82350431');return false;"><span class="mask"></span><img alt="Rock with you" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/350/431/82350431_1634868934488_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/082/350/431/82350431_1634868934488_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('94692075');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('94692075;','1');return false;" title="rock with you
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															Rock with you
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('94692075'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_94692075"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82350431');return false;">
#
#
#
#  													SEVENTEEN 9th Mini Album 'Attacca'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('94692075;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('94692075;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_94692075" onclick="fnAddMyAlbumForm('#add_my_album_94692075' , '94692075' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('94692075');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_94692075">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('94692075','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('94692075');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('94692075');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="94014638">
#  <td class="check"><input class="select-check" title="여전히 아름다운지
#  " type="checkbox"/></td>
#  <td class="number">13</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82183728');return false;"><span class="mask"></span><img alt="여전히 아름다운지" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/183/728/82183728_1628819619146_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/082/183/728/82183728_1628819619146_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('94014638');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('94014638;','1');return false;" title="여전히 아름다운지
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															여전히 아름다운지
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('94014638'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_94014638"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82183728');return false;">
#
#
#
#  													슬기로운 의사생활 시즌2 OST Part 8 (tvN 목요드라마)
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('94014638;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('94014638;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_94014638" onclick="fnAddMyAlbumForm('#add_my_album_94014638' , '94014638' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('94014638');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_94014638">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('94014638','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('94014638');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('94014638');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="87157813">
#  <td class="check"><input class="select-check" title="울고 싶지 않아
#  " type="checkbox"/></td>
#  <td class="number">14</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('80949560');return false;"><span class="mask"></span><img alt="울고 싶지 않아" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/080/949/560/80949560_1495437001969_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/080/949/560/80949560_1495437001969_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('87157813');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('87157813;','1');return false;" title="울고 싶지 않아
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															울고 싶지 않아
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('87157813'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_87157813"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('80949560');return false;">
#
#
#
#  													Al1
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('87157813;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('87157813;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_87157813" onclick="fnAddMyAlbumForm('#add_my_album_87157813' , '87157813' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('87157813');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_87157813">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('87157813','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('87157813');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('87157813');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="97390687">
#  <td class="check"><input class="select-check" title="돌고 돌아
#  " type="checkbox"/></td>
#  <td class="number">15</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82812828');return false;"><span class="mask"></span><img alt="돌고 돌아" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/812/828/82812828_1658125476932_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/082/812/828/82812828_1658125476932_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('97390687');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('97390687;','1');return false;" title="돌고 돌아
#  ">
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															돌고 돌아
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('97390687'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_97390687"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82812828');return false;">
#
#
#
#  													SEVENTEEN 4th Album Repackage 'SECTOR 17'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('97390687;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('97390687;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_97390687" onclick="fnAddMyAlbumForm('#add_my_album_97390687' , '97390687' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('97390687');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_97390687">
#  <a class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('97390687');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('97390687');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="88563933">
#  <td class="check"><input class="select-check" title="home
#  " type="checkbox"/></td>
#  <td class="number">16</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('81151513');return false;"><span class="mask"></span><img alt="Home" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/081/151/513/81151513_1548052828414_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/081/151/513/81151513_1548052828414_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('88563933');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('88563933;','1');return false;" title="home
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															Home
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('88563933'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_88563933"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('81151513');return false;">
#
#
#
#  													SEVENTEEN 6TH MINI ALBUM 'YOU MADE MY DAWN'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('88563933;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('88563933;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_88563933" onclick="fnAddMyAlbumForm('#add_my_album_88563933' , '88563933' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('88563933');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_88563933">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('88563933','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('88563933');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('88563933');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="87529709">
#  <td class="check"><input class="select-check" title="박수
#  " type="checkbox"/></td>
#  <td class="number">17</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('81000375');return false;"><span class="mask"></span><img alt="박수" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/081/000/375/81000375_1509953562318_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/081/000/375/81000375_1509953562318_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('87529709');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('87529709;','1');return false;" title="박수
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															박수
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('87529709'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_87529709"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('81000375');return false;">
#
#
#
#  													TEEN, AGE
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('87529709;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('87529709;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_87529709" onclick="fnAddMyAlbumForm('#add_my_album_87529709' , '87529709' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('87529709');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_87529709">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('87529709','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('87529709');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('87529709');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="88112625">
#  <td class="check"><input class="select-check" title="어쩌나
#  " type="checkbox"/></td>
#  <td class="number">18</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('81084815');return false;"><span class="mask"></span><img alt="어쩌나" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/081/084/815/81084815_1531726476621_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/081/084/815/81084815_1531726476621_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('88112625');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('88112625;','1');return false;" title="어쩌나
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															어쩌나
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('88112625'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_88112625"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('81084815');return false;">
#
#
#
#  													SEVENTEEN 5TH MINI ALBUM 'YOU MAKE MY DAY'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('88112625;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('88112625;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_88112625" onclick="fnAddMyAlbumForm('#add_my_album_88112625' , '88112625' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('88112625');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_88112625">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('88112625','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('88112625');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('88112625');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="90405681">
#  <td class="check"><input class="select-check" title="left &amp; right
#  " type="checkbox"/></td>
#  <td class="number">19</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('81478008');return false;"><span class="mask"></span><img alt="Left &amp; Right" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/081/478/008/81478008_1592812031333_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/081/478/008/81478008_1592812031333_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('90405681');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('90405681;','1');return false;" title="left &amp; right
#  ">
#  <span class="icon icon-title">TITLE</span>
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															Left &amp; Right
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('90405681'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_90405681"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('81478008');return false;">
#
#
#
#  													SEVENTEEN 7th Mini Album '헹가래'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('90405681;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('90405681;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_90405681" onclick="fnAddMyAlbumForm('#add_my_album_90405681' , '90405681' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('90405681');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_90405681">
#  <a class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('90405681','3'); return false;" title="뮤비">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('90405681');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('90405681');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>,
#  <tr class="list" songid="88112630">
#  <td class="check"><input class="select-check" title="우리의 새벽은 낮보다 뜨겁다
#  " type="checkbox"/></td>
#  <td class="number">20</td>
#  <td><a class="cover" href="#" onclick="fnViewAlbumLayer('81084815');return false;"><span class="mask"></span><img alt="우리의 새벽은 낮보다 뜨겁다" onerror="this.src='//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/081/084/815/81084815_1531726476621_1_600x600.JPG';" src="/Y/IMAGE/IMG_ALBUM/081/084/815/81084815_1531726476621_1_600x600.JPG"/></a></td>
#  <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('88112630');return false;">곡 제목 정보 페이지</a></td>
#  <td class="info">
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('88112630;','1');return false;" title="우리의 새벽은 낮보다 뜨겁다
#  ">
#  <!--<span class="icon icon-hot">HOT</span>-->
#  <span class="t_point"></span>
#
#
#
#  															우리의 새벽은 낮보다 뜨겁다
#
#
#  					                            </a>
#  <a class="artist ellipsis" href="#" onclick="fnViewArtist('14945871');return false;">
#  <span class="t_point">세븐틴</span> (SEVENTEEN)
#
#
#
#  					                    </a>
#  <div class="toggle-button-box">
#  <button class="btn artist-etc" onclick="fnRelationArtistList('88112630'); return false;" type="button">외</button>
#  <ul class="list" id="RelationArtist_88112630"></ul>
#  </div>
#  <i class="bar">|</i>
#  <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('81084815');return false;">
#
#
#
#  													SEVENTEEN 5TH MINI ALBUM 'YOU MAKE MY DAY'
#
#
#  					                    </a>
#  </td>
#  <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('88112630;','1');return false;" title="재생">듣기</a></td>
#  <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('88112630;','3');return false;" title="추가">재생목록에 추가</a></td>
#  <td class="btns"><button class="btn-basic btn-album" id="add_my_album_88112630" onclick="fnAddMyAlbumForm('#add_my_album_88112630' , '88112630' ,10, 10);return false;" title="담기" type="button">플레이리스트에 담기</button></td>
#  <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('88112630');return false;" title="다운">다운로드</a></td>
#  <td class="btns">
#  <div class="toggle-button-box lyr-mv" id="list-mv_88112630">
#  <a class="btn btn-basic btn-mv disabled" href="#" onclick="return false;" title="재생 불가">뮤직비디오 보기</a>
#  </div>
#  </td>
#  <td class="more">
#  <div class="toggle-button-box">
#  <button class="btn btn-basic btn-more" type="button">더보기</button>
#  <ul class="list">
#  <li><a class="item" href="#" onclick="shareDo('88112630');return false;" title="공유">공유하기/음악나누기</a></li>
#  <li><a class="item" href="#" onclick="fnGiftSong('88112630');return false;" title="선물">선물하기</a></li>
#  </ul>
#  </div>
#  </td>
#  </tr>]
